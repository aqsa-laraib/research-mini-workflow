# %% [markdown]
# <a href="https://colab.research.google.com/github/aqsa-laraib/research-mini-workflow/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(1,10)
y=x**2
plt.plot(x,y)
plt.title('Squares of a Number')
plt.show()
